# %%
# Day 1 - Environment Setup Check
# AI & ML Internship - Codomax Digital Solutions

print("Environment setup successful!")
print("Project: Predicting Exam Scores from Study Hours using Linear Regression")

hours_studied = 6
print(f"Example input: {hours_studied} hours of study")
print("Model will predict the corresponding exam score in upcoming days.")
# Out:
# Environment setup successful!
# Project: Predicting Exam Scores from Study Hours using Linear Regression
# Example input: 6 hours of study
# Model will predict the corresponding exam score in upcoming days.

# %% [markdown]
# # Day 3 - NumPy
#
# AI & ML Internship - Codomax
#
# Learning numpy arrays today, basic ops and indexing.

# %%
import numpy as np

# %%
# study hours for the week
study_hours = np.array([2, 3, 4, 1, 5, 6, 2])
study_hours

# %%
# indexing - starts from 0
study_hours[0]

# %%
study_hours[-1]

# %%
# slicing
study_hours[0:3]

# %%
study_hours[3:]

# %%
# some quick math
study_hours.sum()

# %%
study_hours.mean()

# %%
study_hours.max(), study_hours.min()

# %%
study_hours * 2

# %%
# 2d array - rows and columns, like study hours vs score
data = np.array([[2, 65], [3, 70], [4, 75], [5, 85]])
data

# %%
data.shape

# %% [markdown]
# Covered arrays, indexing, slicing and basic math today. Moving to Pandas next for the actual dataset.
